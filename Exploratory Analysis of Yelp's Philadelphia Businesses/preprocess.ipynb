# %% [markdown]
# Preprocessing the data:
#     - Filtering out values than are not in Philadelphia
#     - Creating new csv files with only the Philadelphia data

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import json
df1 = pd.read_json('yelp_academic_dataset_business.json', lines=True)
df1.to_csv('yelp_academic_dataset_business.csv',index = False)

# %%
df2 = pd.read_csv('yelp_academic_dataset_business.csv')
df2
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# ...

# %%
df2= df2.loc[df2['city'] == 'Philadelphia']
df2
# Out:
#                    business_id                                 name  \
# 3       MTSW4McQd7CbVtyjqoe9mw                   St Honore Pastries
# 15      MUTTqe8uqyMdBl186RmNeA                             Tuna Bar
# 19      ROeacJQwBeh05Rqg7F6TCg                                  BAP
# 28      QdN72BWoyFypdGJhhI5r7g                              Bar One
# 31      Mjboz24M9NlBeiOJKLEd_Q                     DeSandro on Main
# ...                        ...                                  ...
# 150320  wPAaAbFbq5wfLfW0gnYU7g                             Intermix
# 150326  JDM7kiCEmeBc_5W-z6eZZw              2601 Parkway Apartments
# 150329  9U1Igcpe954LoWZRmNc-zg  Hand & Stone Massage And Facial Spa
# 150334  LJ4GjQ1HL6kqvIPpNUNNaQ             Shanti Yoga and Ayurveda
# 150336  WnT9NIzQgLlILjPT0kEcsQ        Adelita Taqueria & Restaurant
#
#                              address          city state postal_code  \
# 3                        935 Race St  Philadelphia    PA       19107
# ...

# %%
df2.to_csv('yelp_academic_dataset_business.csv',index = False)

# %%
df4 = pd.DataFrame()

# %%
business_id_list = df2["business_id"].values.tolist()
filename = "yelp_academic_dataset_review.json"
review=[]
#maybe not the most memory efficient but didnt prompt a memory error
for chunk in pd.read_json('yelp_academic_dataset_review.json', lines=True, chunksize=1000):

        review.append(chunk[chunk['business_id'].isin(business_id_list)])

# %%
#columns=["review_id","user_id","business_id","stars","useful","funny","cool","text"]

# %%
df7=pd.DataFrame()
#df7= df7.append(review[0], ignore_index = True)

# %%
len(review)
# Out:
# 6991

# %%
for i in range(len(review)):
    df7= df7.append(review[i], ignore_index = True)
# Out:
# /var/folders/gw/2h0k1fwd3x1cfqdc9_7xxxt80000gn/T/ipykernel_56325/2495601937.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df7= df7.append(review[i], ignore_index = True)

# %%
df7
# Out:
#                       review_id                 user_id  \
# 0        4NDQ8gMT4h7tVaromMiotg  VEj1OuO6QrQMXFhuMZJ8cQ
# 1        B8sUIRgisTiHbpdw5X1wMg  -xTAmslBDE_mq-6Kbxieag
# 2        YyiZfDz9UyOgoCy2tBAaPg  CcqpZkc5ngs88akzQ0rFHg
# 3        oHlft2Vve-A-VaB2UCeJXw  64_Kq1IZglMqiyKj1EoAKw
# 4        _21cj3gaLr3lqFUjeVh4Tg  _pIgvX90vh7-yzWMfKeXUA
# ...                         ...                     ...
# 1086338  tWCi4N2qCil876BI2NDAZg  5d32aJe0a3_fSl3LIVYkWQ
# 1086339  nLjbVsETpqO17RbFcqskkA  am7-gkH_PDz598oTdYSD6A
# 1086340  99ylx-qPUSseITqBye2MpA  -AkziDwQ8hv2COTDBBUpig
# 1086341  KlHxcAifUF5zDKpJCBrRsw  7ziWZULyiZv2TesYNMFf4g
# 1086342  cACxcUY_AIsQKkpDRXuqnw  MCzlzlOw7IGbRAKVjJBPtg
#
#                     business_id  stars  useful  funny  cool  \
# 0        NVN_23yYJDf_RAinqFICDA      4       2      2     3
# 1        7yPzOek7Af2dKWGYKpcHWA      4       0      0     1
# 2        7yPzOek7Af2dKWGYKpcHWA      4       0      0     0
# ...

# %%
df7.to_csv('yelp_academic_dataset_reviews.csv',index = False)
